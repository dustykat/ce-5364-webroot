# %% [markdown]
# # Final Examination (Preview)
#
# A preview of the final exam is linked below:
#
# [ce5364-FinalExam-2025-3.pdf Preview](http://54.243.252.9/ce-5364-webroot/ce5364jupyterbook/chapters/FinalExam-2025-3.pdf)
#
#
# :::{warning}
# The actual live exam is served from the Canvas LMS - to earn an exam score it must be completed at that location.
# :::
